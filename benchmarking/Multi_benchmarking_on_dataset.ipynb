# %%
# 📘 SecEval Ollama Benchmark Notebook (Colab)

# 📦 Install dependencies
# !pip install datasets requests
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.32.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# ⚙️ Setup
import time
import requests
from datasets import load_dataset

# 🔗 Replace this with your ngrok/localtunnel/external link
OLLAMA_API = "https://be12-2405-201-e025-f0fb-7464-6fa0-ae1a-e93a.ngrok-free.app/"  # e.g., https://abc123.loca.lt
MODELS = {"qwen2.5-coder:latest","qwen-2.5-coder-tuned:latest","rohits/codellama_finetuned:latest","codellama:7b"}  # or your custom model name in Ollama
NUM_QUESTIONS = 30  # Set how many questions you want to evaluate

# %%
def format_prompt(question, choices):
    formatted_choices = "\n".join([f"{chr(65+i)}. {c}" for i, c in enumerate(choices)])
    return f"""You are given a multiple-choice question.

Strictly Respond ONLY with capital letter of choice: A
if multiple answers are correct respond lik : ABC (if A,B,C are correct then output shd be like this ABC no spaces or commas in middle)

Question:
{question}

Choices:
{formatted_choices}
Answer:"""
import re
def extract_answer(output):
    # Convert to uppercase to simplify matching
    output = output.upper()

    # Match multiple letters: A-D, with optional separators (space, comma, "and")
    matches = re.findall(r'\b[A-D]\b', output)
    if matches:
        # Remove duplicates and sort
        unique_answers = sorted(set(matches))
        return ''.join(unique_answers)

    # Fallback: match combined answers like "AB", "ACD"
    match = re.search(r'\b([A-D]{2,4})\b', output)
    if match:
        return ''.join(sorted(set(match.group(1))))

    return "N/A"

# %%
# 📥 Load dataset
import pandas as pd
from datasets import Dataset
# 🔢 Define number of questions
NUM_QUESTIONS = 30  # Change if needed

print("📥 Loading SecEval dataset from Hugging Face (via hf:// protocol)...")


df = pd.read_json("hf://datasets/XuanwuAI/SecEval/questions.json")

# 🧹 Trim to the first N questions
df = df.iloc[:NUM_QUESTIONS].reset_index(drop=True)

# 🔁 Convert to Hugging Face dataset
dataset = Dataset.from_pandas(df)

print(f"✅ Loaded {len(dataset)} questions")

# 📝 Display a sample
sample = dataset[0]
print(f"\n📝 Sample question:")
print(f"Q: {sample['question']}")
print(f"Choices: {sample['choices']}")
print(f"Answer: {sample['answer']}")
# Out:
# 📥 Loading SecEval dataset from Hugging Face (via hf:// protocol)...
# ✅ Loaded 30 questions
#
# 📝 Sample question:
# Q: You are tasked with designing a secure storage system for an Android device's hardware identifiers as part of an ID attestation implementation. Which of the following properties are essential for ensuring the system's integrity and security?
# Choices: ['A: The storage must contain the original identifiers to enable the TEE to verify their authenticity during attestation.', 'B: The storage should be tamper-evident to ensure any modification is detectable, rendering the attestation invalid.', 'C: The `destroyAttestationIds()` method should be able to restore the identifier-derived data after a factory reset.', 'D: RMA facilities must not have the ability to regenerate hardware identifier-derived data to prevent unauthorized attestation.']
# Answer: B

# %%
results = []

for model_name in MODELS:
    print(f"\n🚀 Benchmarking: {model_name}")

    correct = 0
    latencies = []

    for i, sample in enumerate(dataset):
        print(f"\n🔄 Question {i+1}/{NUM_QUESTIONS}")
        prompt = format_prompt(sample["question"], sample["choices"])

        # Send request to Ollama API
        start = time.time()
        response = requests.post(
            f"{OLLAMA_API}/api/generate",
            json={
                "model": model_name,
                "prompt": prompt,
                "stream": False
            }
        )
        latency = time.time() - start

        try:
            output_text = response.json().get("response", "")
        except Exception:
            output_text = ""

        prediction = extract_answer(output_text)
        actual = sample["answer"].strip().upper()
        is_correct = prediction == actual or all(c in actual for c in prediction)

        print(f"📤 Model's Raw Output: {output_text.strip()[:200]}")
        print(f"📝 Prediction: {prediction}")
        print(f"✅ Actual Answer: {actual}")
        print(f"🎯 Correct? {'✅ Yes' if is_correct else '❌ No'}")
        print(f"⏱️ Latency: {latency:.2f} s")

        correct += int(is_correct)
        latencies.append(latency)

    accuracy = correct / NUM_QUESTIONS * 100
    avg_latency = sum(latencies) / NUM_QUESTIONS

    results.append({
        "Model": model_name,
        "Accuracy (%)": round(accuracy, 2),
        "Avg Latency (s)": round(avg_latency, 2),
        "Correct Answers": correct,
        "Total Questions": NUM_QUESTIONS
    })

# 📊 Final Summary
results = sorted(results, key=lambda x: x["Accuracy (%)"], reverse=True)

print("\n🏁 Final Ranking:")
for i, r in enumerate(results, 1):
    print(f"{i}. {r['Model']} — {r['Accuracy (%)']}% accuracy | ⏱ {r['Avg Latency (s)']}s avg latency")
# Out:
# 🚀 Benchmarking: qwen2.5-coder:latest
#
# 🔄 Question 1/30
# 📤 Model's Raw Output: A B D
# 📝 Prediction: ABD
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 9.72 s
#
# 🔄 Question 2/30
# 📤 Model's Raw Output: B
# 📝 Prediction: B
# ✅ Actual Answer: B
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.36 s
#
# 🔄 Question 3/30
# 📤 Model's Raw Output: B
# 📝 Prediction: B
# ✅ Actual Answer: B
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.34 s
#
# 🔄 Question 4/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.30 s
#
# 🔄 Question 5/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.33 s
#
# 🔄 Question 6/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.34 s
#
# 🔄 Question 7/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.36 s
#
# 🔄 Question 8/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.34 s
#
# 🔄 Question 9/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.32 s
#
# 🔄 Question 10/30
# 📤 Model's Raw Output: A, D
# 📝 Prediction: AD
# ✅ Actual Answer: AD
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.34 s
#
# 🔄 Question 11/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.34 s
#
# 🔄 Question 12/30
# 📤 Model's Raw Output: D
# 📝 Prediction: D
# ✅ Actual Answer: CD
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.30 s
#
# 🔄 Question 13/30
# 📤 Model's Raw Output: A B
# 📝 Prediction: AB
# ✅ Actual Answer: BD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.35 s
#
# 🔄 Question 14/30
# 📤 Model's Raw Output: A C
# 📝 Prediction: AC
# ✅ Actual Answer: AC
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.35 s
#
# 🔄 Question 15/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.31 s
#
# 🔄 Question 16/30
# 📤 Model's Raw Output: D
# 📝 Prediction: D
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.35 s
#
# 🔄 Question 17/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: ABC
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.35 s
#
# 🔄 Question 18/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.37 s
#
# 🔄 Question 19/30
# 📤 Model's Raw Output: C
# 📝 Prediction: C
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.29 s
#
# 🔄 Question 20/30
# 📤 Model's Raw Output: B
# 📝 Prediction: B
# ✅ Actual Answer: B
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.34 s
#
# 🔄 Question 21/30
# 📤 Model's Raw Output: B
# 📝 Prediction: B
# ✅ Actual Answer: AC
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.40 s
#
# 🔄 Question 22/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.36 s
#
# 🔄 Question 23/30
# 📤 Model's Raw Output: A D
# 📝 Prediction: AD
# ✅ Actual Answer:
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.37 s
#
# 🔄 Question 24/30
# 📤 Model's Raw Output: A CD
# 📝 Prediction: A
# ✅ Actual Answer: AB
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.39 s
#
# 🔄 Question 25/30
# 📤 Model's Raw Output: A C D
# 📝 Prediction: ACD
# ✅ Actual Answer: ACD
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.44 s
#
# 🔄 Question 26/30
# 📤 Model's Raw Output: AD
# 📝 Prediction: AD
# ✅ Actual Answer: AD
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.36 s
#
# 🔄 Question 27/30
# 📤 Model's Raw Output: B C D
# 📝 Prediction: BCD
# ✅ Actual Answer: BCD
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.42 s
#
# 🔄 Question 28/30
# 📤 Model's Raw Output: B
# 📝 Prediction: B
# ✅ Actual Answer: B
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.30 s
#
# 🔄 Question 29/30
# 📤 Model's Raw Output: B
# 📝 Prediction: B
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.34 s
#
# 🔄 Question 30/30
# 📤 Model's Raw Output: AB
# 📝 Prediction: AB
# ✅ Actual Answer: AB
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.31 s
#
# 🚀 Benchmarking: rohits/codellama_finetuned:latest
#
# 🔄 Question 1/30
# 📤 Model's Raw Output: The correct answer is A: The storage must contain the original identifiers to enable the TEE to verify their authenticity during attestation. This is essential for ensuring the system's integrity and
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 9.57 s
#
# 🔄 Question 2/30
# 📤 Model's Raw Output: The correct answer is A: Using SharedPreferences with MODE_PRIVATE to store user preferences and settings. This option should be avoided because it allows other applications on the device to access th
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 1.92 s
#
# 🔄 Question 3/30
# 📤 Model's Raw Output: A: Automated security activities can slow down the delivery process, ensuring that only high-priority features are shipped.
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 1.19 s
#
# 🔄 Question 4/30
# 📤 Model's Raw Output: The correct answer is A: The attacker could potentially learn the encryption keys from the handshake and decrypt messages.
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 1.13 s
#
# 🔄 Question 5/30
# 📤 Model's Raw Output: A. Inspecting the application's source code to identify places where input is directly included into dynamic queries or commands without proper sanitization.
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 1.34 s
#
# 🔄 Question 6/30
# 📤 Model's Raw Output: A: Because the keys are bound to the operating system version and are invalidated if the device is rolled back to a vulnerable version.
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 1.20 s
#
# 🔄 Question 7/30
# 📤 Model's Raw Output: The correct response is A, B, C.
#
# A. The internal state 'K' and 'V' is updated after generating the pseudorandom bits to ensure that the next output cannot be predicted if the current state is comprom
# 📝 Prediction: ABCD
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 8.64 s
#
# 🔄 Question 8/30
# 📤 Model's Raw Output: A: When FileVault is off, the volume encryption key is only protected by the hardware UID, and enabling FileVault later will secure the volume with both the user's password and hardware UID. The Secur
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 2.65 s
#
# 🔄 Question 9/30
# 📤 Model's Raw Output: A: Monitoring network throughput for significant drops, which can indicate a system shutdown.
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.96 s
#
# 🔄 Question 10/30
# 📤 Model's Raw Output: A and C
# 📝 Prediction: AC
# ✅ Actual Answer: AD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.39 s
#
# 🔄 Question 11/30
# 📤 Model's Raw Output: The correct answer is A.
#
# In the ARP protocol, Alice's computer sends a broadcast message to the LAN asking for the MAC address of Bob's IP address. This is done using the "who-has" message type in th
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 4.15 s
#
# 🔄 Question 12/30
# 📤 Model's Raw Output: I would respond with: ABC (Incorrect choice)
#
# The correct countermeasure for preventing clickjacking attacks is A: Implementing Content Security Policy (CSP) headers to restrict where resources can be
# 📝 Prediction: AD
# ✅ Actual Answer: CD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 5.70 s
#
# 🔄 Question 13/30
# 📤 Model's Raw Output: A: Implementing a robust intrusion detection system that can recognize patterns typical of exploitation attempts.
# C: Setting up a firewall to filter out malicious IP addresses and prevent attackers fr
# 📝 Prediction: AC
# ✅ Actual Answer: BD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 1.85 s
#
# 🔄 Question 14/30
# 📤 Model's Raw Output: The correct answer is A: It can lead to tighter coupling between components, making the codebase harder to maintain and understand.
#
# Explanation: While global variables may provide a performance boost
# 📝 Prediction: A
# ✅ Actual Answer: AC
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 2.84 s
#
# 🔄 Question 15/30
# 📤 Model's Raw Output: The correct answer is A: Because platform-independent security measures provide a consistent baseline for all mobile apps regardless of the underlying operating system.
#
# Explanation: Platform-independ
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 3.16 s
#
# 🔄 Question 16/30
# 📤 Model's Raw Output: The correct answer is A: Setting up alerts for system-related events that might indicate potential security breaches.
#
# Reason: While monitoring 'Other Events' auditing subcategory can provide valuable
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 3.84 s
#
# 🔄 Question 17/30
# 📤 Model's Raw Output: The correct answer is A: Enabling the -disable-reset-capability option to prevent firmware password reset via software means.
#
# This action can effectively contribute to securing the Mac systems agains
# 📝 Prediction: A
# ✅ Actual Answer: ABC
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 2.77 s
#
# 🔄 Question 18/30
# 📤 Model's Raw Output: A. A: The IP address '10.0.0.1' is commonly used as a default gateway, potentially resulting in network routing issues if used for the server.
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 1.50 s
#
# 🔄 Question 19/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.33 s
#
# 🔄 Question 20/30
# 📤 Model's Raw Output: A. A: The adversary uses a custom, proprietary encryption algorithm instead of a known secure one.
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 1.01 s
#
# 🔄 Question 21/30
# 📤 Model's Raw Output: C. C: public boolean CheckAccess(String password) { final String KEY = System.getenv("APP_SECRET_KEY"); return password.equals(KEY); }
#
# This choice does not demonstrate the vulnerability associated wi
# 📝 Prediction: ABCD
# ✅ Actual Answer: AC
# 🎯 Correct? ❌ No
# ⏱️ Latency: 14.79 s
#
# 🔄 Question 22/30
# 📤 Model's Raw Output: The correct answer is A: Root server provides '.com' NS; '.com' server provides 'example.com' NS; 'example.com' server provides 'dept.example.com' IP.
#
# This sequence correctly reflects the DNS resolut
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 4.47 s
#
# 🔄 Question 23/30
# 📤 Model's Raw Output: The correct answer is A. Monitor for the creation of new services under network logon sessions by non-system users. This method can be effective in identifying unauthorized use of valid accounts via r
# 📝 Prediction: A
# ✅ Actual Answer:
# 🎯 Correct? ❌ No
# ⏱️ Latency: 2.23 s
#
# 🔄 Question 24/30
# 📤 Model's Raw Output: The correct answer is A: The use of the Key encryption key (KEK) to protect the Owner Identity Key (OIK) with the selected user's password for the new operating system.
#
# This is crucial to ensure a se
# 📝 Prediction: ABCD
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 10.55 s
#
# 🔄 Question 25/30
# 📤 Model's Raw Output: The correct answer is A: Implementing a limit on the number of unsuccessful login attempts before locking the account.
#
# This measure could potentially reduce the risk of successful attacks by making i
# 📝 Prediction: ABCD
# ✅ Actual Answer: ACD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 9.12 s
#
# 🔄 Question 26/30
# 📤 Model's Raw Output: The correct answer is A: Storing OAuth tokens in encrypted form within the application's local storage to prevent unauthorized access. This is a security best practice because it ensures that sensitiv
# 📝 Prediction: A
# ✅ Actual Answer: AD
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 2.16 s
#
# 🔄 Question 27/30
# 📤 Model's Raw Output: The correct answer is C. Store HomeKit data on the device using the Data Protection class Protected Until First User Authentication and encrypt backups with HomeKit identity keys and a random nonce.
#
#
# 📝 Prediction: ABCD
# ✅ Actual Answer: BCD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 7.39 s
#
# 🔄 Question 28/30
# 📤 Model's Raw Output: The correct answer is A: Increased granularity in file system access control and auditing.
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 1.00 s
#
# 🔄 Question 29/30
# 📤 Model's Raw Output: The correct answer is A. The device does not meet the baseline requirements for System Guard, Device Guard, Credential Guard, and Virtualization Based Security.
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 1.33 s
#
# 🔄 Question 30/30
# 📤 Model's Raw Output: A, B, C
# 📝 Prediction: ABC
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.46 s
#
# 🚀 Benchmarking: codellama:7b
#
# 🔄 Question 1/30
# 📤 Model's Raw Output: The correct answer is ABC.
#
# A) The storage must contain the original identifiers to enable the TEE to verify their authenticity during attestation. This ensures that the system's integrity and securit
# 📝 Prediction: ABC
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 8.49 s
#
# 🔄 Question 2/30
# 📤 Model's Raw Output: The correct answer is A: Using SharedPreferences with MODE_PRIVATE to store user preferences and settings.
#
# Storing user credentials in an unencrypted SQLite database accessible to the app is a bad pr
# 📝 Prediction: ABC
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 4.68 s
#
# 🔄 Question 3/30
# 📤 Model's Raw Output: The correct answer is B: Automated security activities are crucial to CI/CD pipeline because the frequency of deliveries increases, necessitating the automation of security activities to maintain an a
# 📝 Prediction: B
# ✅ Actual Answer: B
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 1.35 s
#
# 🔄 Question 4/30
# 📤 Model's Raw Output: The answer is A:
#
# A likely consequence of an on-path attack in a wireless local network that is not secured using WPA2-Enterprise would be that the attacker could potentially learn the encryption keys
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 2.19 s
#
# 🔄 Question 5/30
# 📤 Model's Raw Output: The most effective step in identifying and assessing potential injection points for code execution vulnerabilities would be to inspect the application's source code to identify places where input is d
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 3.78 s
#
# 🔄 Question 6/30
# 📤 Model's Raw Output: The correct answer is A: Because the keys are bound to the operating system version and are invalidated if the device is rolled back to a vulnerable version.
#
# Explain: The version binding in Android p
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 3.18 s
#
# 🔄 Question 7/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.39 s
#
# 🔄 Question 8/30
# 📤 Model's Raw Output: A. A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.42 s
#
# 🔄 Question 9/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.36 s
#
# 🔄 Question 10/30
# 📤 Model's Raw Output: A and C
# 📝 Prediction: AC
# ✅ Actual Answer: AD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.39 s
#
# 🔄 Question 11/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.39 s
#
# 🔄 Question 12/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: CD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.35 s
#
# 🔄 Question 13/30
# 📤 Model's Raw Output: The correct actions for preventing similar incidents in the future include:
# A. Implementing a robust intrusion detection system that can recognize patterns typical of exploitation attempts.
# B. Advisin
# 📝 Prediction: AB
# ✅ Actual Answer: BD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 2.38 s
#
# 🔄 Question 14/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer: AC
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.35 s
#
# 🔄 Question 15/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.32 s
#
# 🔄 Question 16/30
# 📤 Model's Raw Output: The correct answer is A: Setting up alerts for system-related events that might indicate potential security breaches.
#
# The 'Other Events' auditing subcategory in Windows provides a broad range of even
# 📝 Prediction: A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 3.75 s
#
# 🔄 Question 17/30
# 📤 Model's Raw Output: The answer is A: Enabling the -disable-reset-capability option to prevent firmware password reset via software means.
#
# Enabling this option ensures that the firmware password cannot be reset by any so
# 📝 Prediction: A
# ✅ Actual Answer: ABC
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 2.73 s
#
# 🔄 Question 18/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.33 s
#
# 🔄 Question 19/30
# 📤 Model's Raw Output: The correct answer is B: Implementing strict mode to limit the permissions granted to the application.
#
# Strict Mode restricts an application from accessing features that are not intended for public us
# 📝 Prediction: B
# ✅ Actual Answer: B
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 2.04 s
#
# 🔄 Question 20/30
# 📤 Model's Raw Output: The correct answer is: B
# 📝 Prediction: B
# ✅ Actual Answer: B
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.47 s
#
# 🔄 Question 21/30
# 📤 Model's Raw Output: The correct answer is C. CheckAccess(String password) { final String KEY = System.getenv("APP_SECRET_KEY"); return password.equals(KEY); }
#
# This code snippet uses the System.getenv() method to retriev
# 📝 Prediction: AC
# ✅ Actual Answer: AC
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 3.34 s
#
# 🔄 Question 22/30
# 📤 Model's Raw Output: The correct sequence for the DNS resolution process for the domain 'dept.example.com' is:
# A. A: Root server provides '.com' NS; '.com' server provides 'example.com' NS; 'example.com' server provides '
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 2.16 s
#
# 🔄 Question 23/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer:
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.31 s
#
# 🔄 Question 24/30
# 📤 Model's Raw Output: C
# 📝 Prediction: C
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.32 s
#
# 🔄 Question 25/30
# 📤 Model's Raw Output: A. Implementing a limit on the number of unsuccessful login attempts before locking the account.
# B. Advising users to create passwords containing a sequence of simple patterns, such as '123456'.
# C. Us
# 📝 Prediction: ABC
# ✅ Actual Answer: ACD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 2.20 s
#
# 🔄 Question 26/30
# 📤 Model's Raw Output: The correct answer is A: Storing OAuth tokens in encrypted form within the application's local storage to prevent unauthorized access.
#
# Storing OAuth tokens in an encrypted form can help protect them
# 📝 Prediction: A
# ✅ Actual Answer: AD
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 6.31 s
#
# 🔄 Question 27/30
# 📤 Model's Raw Output: C. Store HomeKit data on the device using the Data Protection class Protected Until First User Authentication and encrypt backups with HomeKit identity keys and a random nonce.
# 📝 Prediction: AC
# ✅ Actual Answer: BCD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 1.29 s
#
# 🔄 Question 28/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.28 s
#
# 🔄 Question 29/30
# 📤 Model's Raw Output: A
# 📝 Prediction: A
# ✅ Actual Answer: A
# 🎯 Correct? ✅ Yes
# ⏱️ Latency: 0.31 s
#
# 🔄 Question 30/30
# 📤 Model's Raw Output: ABC
# 📝 Prediction: ABC
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.33 s
#
# 🚀 Benchmarking: qwen-2.5-coder-tuned:latest
#
# 🔄 Question 1/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.18 s
#
# 🔄 Question 2/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 3/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.19 s
#
# 🔄 Question 4/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.16 s
#
# 🔄 Question 5/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.19 s
#
# 🔄 Question 6/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.20 s
#
# 🔄 Question 7/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.24 s
#
# 🔄 Question 8/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.22 s
#
# 🔄 Question 9/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.18 s
#
# 🔄 Question 10/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: AD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.19 s
#
# 🔄 Question 11/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.20 s
#
# 🔄 Question 12/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: CD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.19 s
#
# 🔄 Question 13/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: BD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.20 s
#
# 🔄 Question 14/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: AC
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.19 s
#
# 🔄 Question 15/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.19 s
#
# 🔄 Question 16/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.20 s
#
# 🔄 Question 17/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: ABC
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.18 s
#
# 🔄 Question 18/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.18 s
#
# 🔄 Question 19/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.19 s
#
# 🔄 Question 20/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.19 s
#
# 🔄 Question 21/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: AC
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 22/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 23/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer:
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 24/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 25/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: ACD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 26/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: AD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 27/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: BCD
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 28/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: B
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 29/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: A
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🔄 Question 30/30
# 📤 Model's Raw Output:
# 📝 Prediction: N/A
# ✅ Actual Answer: AB
# 🎯 Correct? ❌ No
# ⏱️ Latency: 0.17 s
#
# 🏁 Final Ranking:
# 1. qwen2.5-coder:latest — 70.0% accuracy | ⏱ 0.66s avg latency
# 2. codellama:7b — 46.67% accuracy | ⏱ 1.84s avg latency
# 3. rohits/codellama_finetuned:latest — 40.0% accuracy | ⏱ 3.65s avg latency
# 4. qwen-2.5-coder-tuned:latest — 0.0% accuracy | ⏱ 0.19s avg latency
